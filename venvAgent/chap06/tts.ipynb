# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=api_key)

response = client.audio.speech.create(
    model="tts-1-hd",
    voice = "alloy",
    input="Hello world! this is a TTS test",
)

response.write_to_file("hello_world.mp3")

import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
voice = "ash"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model="tts-1-hd",
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test.",
)

response.write_to_file(mp3_file)

import IPython.display as ipd
ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

with open('../chap06/data/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f)
    
eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n\n- (1) Many people are gathered in a large hall.\n- (2) There are bright-colored posters on the wall.\n- (3) People are using laptops.\n- (4) The lights on the ceiling are turned off.',
#   'img': 'busan_dive.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) It shows the inside of a café.\n- (2) One of the walls is yellow.\n- (3) Two people are serving.\n- (4) The outside is visible through the windows.',
#   'img': 'local_stitch_terrarosa.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are chatting in a cafe.\n- (2) The blue sky is visible through the windows.\n- (3) The floor is finished with wood.\n- (4) Several lights are installed on the ceiling.',
#   'img': 'seolleung_terrarosa.jpg'},
#  {'no': 4,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) There are several people on the boat.\n- (2) A yellow statue is at the front of the boat.\n- (3) The boat is docked on the water.\n- (4) The operator is wearing a red and white striped shirt.',
#   'img': 'testImg.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'sage', 'shimmer']

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "One.\t")
    quiz = quiz.replace("- (2)", "Two.\t")
    quiz = quiz.replace("- (3)", "Three.\t")
    quiz = quiz.replace("- (4)", "Four.\t")
    
    print(no, quiz)

    voice = voices[no % len(voices)]

    response = client.audio.speech.create(
    model="tts-1-hd",
    voice=voice,
    input=f'#{no}, {quiz}',
    )

    response.write_to_file(f"../chap06/data/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
#
# One.	 Many people are gathered in a large hall.
# Two.	 There are bright-colored posters on the wall.
# Three.	 People are using laptops.
# Four.	 The lights on the ceiling are turned off.
# 2 Which of the following descriptions of the image is incorrect?
# One.	 It shows the inside of a café.
# Two.	 One of the walls is yellow.
# Three.	 Two people are serving.
# Four.	 The outside is visible through the windows.
# 3 Which of the following descriptions of the image is incorrect?
# One.	 People are chatting in a cafe.
# Two.	 The blue sky is visible through the windows.
# Three.	 The floor is finished with wood.
# Four.	 Several lights are installed on the ceiling.
# 4 Which of the following descriptions of the image is incorrect?
# One.	 There are several people on the boat.
# Two.	 A yellow statue is at the front of the boat.
# Three.	 The boat is docked on the water.
# Four.	 The operator is wearing a red and white striped shirt.
