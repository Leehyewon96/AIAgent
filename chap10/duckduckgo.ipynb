# %%
from langchain_openai import ChatOpenAI


model = ChatOpenAI(model="gpt-4o-mini")
model.invoke("최근 로제가 발표한 신곡은 무엇인가요?")
# Out:
# AIMessage(content='2023년 9월 16일에 로제(ROSÉ)가 새로운 솔로 곡 "On The Ground"와 "GONE"의 리믹스 버전을 발표했습니다. 이 두 곡은 원래 2021년에 발매된 그녀의 첫 솔로 프로젝트에서 제공된 곡들입니다. 혹시 더 알고 싶은 내용이 있으신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 19, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DQQODujZv34UWtIkauH2m5r5MbA7u', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d5196-f16c-7b30-b310-5f1f1a4c75f1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 81, 'total_tokens': 100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %pip install duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Collecting lxml>=5.3.0
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#      ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.0 MB 2.0 MB/s eta 0:00:02
#      - -------------------------------------- 0.2/4.0 MB 2.5 MB/s eta 0:00:02
#      -- ------------------------------------- 0.2/4.0 MB 1.9 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/4.0 MB 2.7 MB/s eta 0:00:02
#      ------ --------------------------------- 0.7/4.0 MB 3.4 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.2/4.0 MB 5.0 MB/s eta 0:00:01
#      -------------- ------------------------- 1.4/4.0 MB 5.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.3/4.0 MB 7.2 MB/s eta 0:00:01
#      ------------------------------ --------- 3.1/4.0 MB 9.0 MB/s eta 0:00:01
#      ----------------------------------- ---- 3.6/4.0 MB 9.6 MB/s eta 0:00:01
#      ---------------------------------------- 4.0/4.0 MB 9.9 MB/s eta 0:00:00
# Collecting primp>=0.15.0
#   Downloading primp-1.2.1-cp310-abi3-win_amd64.whl (3.9 MB)
#      ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#      ----------- ---------------------------- 1.1/3.9 MB 35.5 MB/s eta 0:00:01
#      ------------------- -------------------- 1.9/3.9 MB 29.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.8/3.9 MB 25.8 MB/s eta 0:00:01
#      ---------------------------------------  3.9/3.9 MB 27.5 MB/s eta 0:00:01
#      ---------------------------------------- 3.9/3.9 MB 24.7 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.1.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from duckduckgo-search) (8.3.1)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Installing collected packages: primp, lxml, duckduckgo-search
# Successfully installed duckduckgo-search-8.1.1 lxml-6.0.2 primp-1.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -U ddgs
# Out:
# Collecting ddgs
#   Downloading ddgs-9.12.0-py3-none-any.whl (45 kB)
#      ---------------------------------------- 0.0/45.5 kB ? eta -:--:--
#      ---------------------------------- --- 41.0/45.5 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 45.5/45.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: primp>=1.2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (1.2.1)
# Requirement already satisfied: click>=8.1.8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (8.3.1)
# Requirement already satisfied: lxml>=4.9.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from ddgs) (6.0.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from click>=8.1.8->ddgs) (0.4.6)
# Installing collected packages: ddgs
# Successfully installed ddgs-9.12.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults(results_separator=';\n')
docs = search.invoke("최근 로제가 발표한 신곡은 무엇인가요?")

print(docs)
# Out:
# snippet: 지난해 10월로제가세계적 가수 브루노 마스와 함께발표한곡 'APT.'(아파트)가최근빌보드 메인 차트인 '핫 100'에서 2주 연속 3위를 차지하며 대중적 인기를 과시하고 있기 때문이다., title: 2년간 K팝 잊은 그래미…내년로제가자존심 회복시킬까 [N초점] - 뉴스1, link: https://www.news1.kr/entertain/music/5682705;
# snippet: 블랙핑크로제가최근브루노 마스와 협력하여발표한신곡 ‘APT.’가 발매 즉시 글로벌 차트 정상에 오르며, 그녀의 높은 인기를 입증하고 있다., title: 차트 1위 블랙핑크, 재산200억로제가타는 이 차? | 브런치, link: https://brunch.co.kr/@c8ba214e7725479/8;
# snippet: 걸그룹 블랙핑크의로제가빌보드 글로벌 차트 정상을 찍은 곡 ‘아파트’(APT.) 탄생 비화를 소개했다. 브루노 마스 쪽에 3곡의 협업곡 후보를 제시했는데, 브루노 마스가 ‘아파트’를 콕 집었다는 것이다., title: 로제가보낸 3곡 중 ‘아파트’ 고른 브루노 마스…“끝내주네”, link: https://v.daum.net/v/20241107100042104;
# snippet: 지난 2월발표한데뷔 앨범 'Alter Ego'의 수록곡을 노래하고 랩하며 관객을 사로잡았다. 이틀 뒤인 일요일, 제니 또한 코첼라에서 솔로 무대를 펼쳤고, 리사와로제가관객석에서 함께 응원했다., title: 리사 코첼라 솔로 무대 후,로제가전한 다정한 인터뷰 | Billboard Korea, link: https://billboard.co.kr/editorial/news/article/blackpink-rose-lisa/

# %%
# 질의 확장 구현하기
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "아래 context에 기반하여 사용자의 질문에 답변하라.:\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

document_chain = question_answering_prompt | model

# %%
from langchain_community.chat_message_histories import ChatMessageHistory

# 채팅 메세지를 저장할 메모리 객체 생성
chat_history = ChatMessageHistory()

# 사용자 질문을 메모리에 저장
chat_history.add_user_message("요즘 로제가 발표한 신곡은 무엇인가요?")

# 문서 검색하고 답변 생성
answer = document_chain.invoke(
    {
        "messages":chat_history.messages,
        "context":docs,
    }
)

# 생성된 답변을 메모리에 저장
chat_history.add_ai_message(answer)

print(answer)
# Out:
# content="로제가 최근 발표한 신곡은 브루노 마스와 함께한 'APT.'(아파트)입니다. 이 곡은 발매 즉시 글로벌 차트 정상에 오르며 대중적인 인기를 얻고 있습니다." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 502, 'total_tokens': 552, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a5086b7b9a', 'id': 'chatcmpl-DQQdXODiXvylfXEfbXVuXWw9RTC2V', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019d51a5-6c4a-7641-9e08-dbdaeb76edbb-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 502, 'output_tokens': 50, 'total_tokens': 552, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# DuckDuckGo API 래퍼를 사용하여 검색할 때 검색 매개변수를 설정하는 클래스 import
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

# 한국 지역("kr-kr")을 기준, 최근 일주일("w") 내의 검색 결과를 가져오도록 초기화
wrapper = DuckDuckGoSearchAPIWrapper(region="kr-kr", time="w")

# %%
# 검색 기능을 위한 DuckDcukGoSearchResults 초기화
search = DuckDuckGoSearchResults(
    api_wrapper=wrapper, # 앞에서 정의한 API 래퍼를 사용
    source="news", # 뉴스 소스에서만 검색하도록 지정
    results_separator=';\n' # 검색 항목 사이에 구분자 사용(세미콜론과 줄바꿈)
)

# %%
# "로제의 신곡 APT에 대한 반응"을 검색하고 결과를 docs에 저장
docs = search.invoke("로제의 신곡 APT에 대한 반응")

print(docs)
# Out:
# snippet: 골든도 처음 빌보드 1위 했을 때만 해도 압도적인 스트리밍에 비해 라디오 에어플레이가 낮았지만, title: 포브스 "케데헌이 로제의 라디오 기록을 깼습니다." : 클리앙, link: https://www.clien.net/service/board/park/19169732;
# snippet: 블랙핑크 로제 LA 애프터파티반응폭발 이유 콘서트와 시상식이 몰리는 요즘, 무대 뒤에서 벌어지는 애프터파티도 함께 주목받고 있습니다. 그중에서도 블랙핑크 로제 LA 관련 소식은 공개될 때마다 큰 반응을 이끌죠. 왜로제의LA 애프터파티 현장이 이렇게까지 화제가 되는 걸까요? 현장의 분위기 ..., title: 블랙핑크 로제 La 애프터파티 반응 폭발 이유 ㅣ 판다랭크, link: https://pandarank.net/contents/693b6c50fb9cd141f1bf5d1b;
# snippet: - 40년 만의 역주행 신화, MZ세대부터 시니어까지 '진짜 아파트'에 열광 - 단순 추억 팔이 NO! 50년 음악 인생 집대성한 '현재진행형 레전드'의 저력 전 세계를 흔든로제의'아파트 (APT.)'열풍, 그 뿌리가 되는 대한민국 록의 거장 윤수일이 마침내 움직인다., title: nakyong2(PNL BIO), link: https://nakyong2.tistory.com/;
# snippet: [OSEN=지민경 기자] 아티스트 로제가 '아이하트라디오' 2관왕에 등극했다. 지난 26일 (이하 현지 시간) 미국 로스앤젤레스에서 개최된 '2026 아이하트라디오 뮤직 어워즈 (iHeart Radio Music Awards 2026)'에서 로제가 브루노 마스와의 듀엣 곡'APT.'(아파트)로 '베스트 컬래버레이션'과 '올해의 K팝 아티스트' 두 ..., title: 로제 '아파트', 2026년에도 신드롬ing..美 아이하트라디오 '2관왕', link: https://www.chosun.com/entertainments/music/2026/03/28/MZQTCM3BGA2TOZDDMYZTAOBYMM/

# %%
# DuckDuckGo를 이용해 ytn.co.kr 웹 사이트에서 로제의 신곡 APT에 대한 분석을 검색
docs = search.invoke("site:ytn.co.kr 로제의 신곡 APT 분석")
docs
# Out:
# "snippet: 로제와 브루노 마스의 ‘APT.’는 오는 12월 6일로제의정식 컴백을 앞두고 발매된 선공개 싱글이다., title: [Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작, link: https://star.ytn.co.kr/_sn/0117_202410310830016352;\nsnippet: 'APT.'가 수록되는로제의첫 번째 정규 앨범 '로지(rosie)'는 오는 12월 6일 발매된다. YTN star 오지원 (bluejiwon@ytn.co.kr)., title: [가요]'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권, link: https://star.ytn.co.kr/_sn/0117_202410221526301537_001;\nsnippet: [앵커] 블랙핑크로제의신곡'아파트'의 뮤직비디오가 발표 닷새 만에 1억 조회 수를 돌파했습니다., title: [문화] 로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁 | YTN, link: https://ytn.co.kr/_ln/0106_202410240027036166;\nsnippet: 로제의정규 1집 '‘rosie’의 선공개 싱글 'APT.'는 써클지수 19,917,013을 기록하며 두 아티스트의 글로벌 인기를 입증했다. 이 곡은 특히 글로벌 K-pop 차트와 스트리밍 차트에서 10주 연속 1위를 유지하며 장기 흥행 중이다. 드림캐쳐는 '[My Christmas Sweet Love] (POCA)..., title: [가요] 로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성 | YTN, link: https://star.ytn.co.kr/_sn/0117_202501021123559073"

# %%
# 검색 결과의 링크들을 저장할 빈 리스트 초기화
links = []

# 검색 결과를 세미콜론과 줄 바꿈 기준으로 분리하고, 각 결과 항목에서 링크 추출
for doc in docs.split(";\n"):
    print(doc) # 각 검색 결과 항목을 출력하여 확인
    link=doc.split("link:")[1].strip() # 각 항목에서 'link:'이후의 URL 부분만 추출
    links.append(link) # 추출한 링크를 리스트에 추가

# 모든 링크를 출력
print(links)
# Out:
# snippet: 로제와 브루노 마스의 ‘APT.’는 오는 12월 6일로제의정식 컴백을 앞두고 발매된 선공개 싱글이다., title: [Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작, link: https://star.ytn.co.kr/_sn/0117_202410310830016352
# snippet: 'APT.'가 수록되는로제의첫 번째 정규 앨범 '로지(rosie)'는 오는 12월 6일 발매된다. YTN star 오지원 (bluejiwon@ytn.co.kr)., title: [가요]'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권, link: https://star.ytn.co.kr/_sn/0117_202410221526301537_001
# snippet: [앵커] 블랙핑크로제의신곡'아파트'의 뮤직비디오가 발표 닷새 만에 1억 조회 수를 돌파했습니다., title: [문화] 로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁 | YTN, link: https://ytn.co.kr/_ln/0106_202410240027036166
# snippet: 로제의정규 1집 '‘rosie’의 선공개 싱글 'APT.'는 써클지수 19,917,013을 기록하며 두 아티스트의 글로벌 인기를 입증했다. 이 곡은 특히 글로벌 K-pop 차트와 스트리밍 차트에서 10주 연속 1위를 유지하며 장기 흥행 중이다. 드림캐쳐는 '[My Christmas Sweet Love] (POCA)..., title: [가요] 로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성 | YTN, link: https://star.ytn.co.kr/_sn/0117_202501021123559073
# ['https://star.ytn.co.kr/_sn/0117_202410310830016352', 'https://star.ytn.co.kr/_sn/0117_202410221526301537_001', 'https://ytn.co.kr/_ln/0106_202410240027036166', 'https://star.ytn.co.kr/_sn/0117_202501021123559073']

# %%
# %pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 랭체인의 WebBaseLoader를 사용하여 웹 페이지의 내용 불러오기
from langchain_community.document_loaders import WebBaseLoader

# WebBaseLoader 객체를 생성. 'links'는 웹 페이지의 URL 목록을 담고 있는 변수
# bs_get_text_kwargs는 BeautifulSoup의 get_text() 메서드에 전달될 추가 인자
loader = WebBaseLoader(
    web_paths=links, # 웹 페이지의 링크 목록을 지정
    bs_get_text_kwargs={
        "strip":True, # 웹 페이지에서 텍스트를 가져올 때 앞뒤의 공백 제거
    }
)

# 비동기로 웹 페이지의 내용을 로드하고, 각 문서를 page_contents 리스트에 추가
page_contents = [] # 각 웹 페이지의 내용을 저장할 리스트
async for doc in loader.alazy_load():
    page_contents.append(doc) # 불러온 문서를 page_contents 리스트에 추가

# page_contents에 있는 각 웹 페이지의 내용 출력
for content in page_contents:
    print(content) # 웹 페이지의 내용 출력
    print('------------------------------------') # 웹 페이지를 구분하는 구분선 출력
# Out:
# Fetching pages: 100%|##########| 4/4 [00:00<00:00,  6.36it/s]
# page_content='[Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램[Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기[Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작2024.10.31. 오전 08:30.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기이미지 확대 보기AD로제와 브루노 마스의 듀엣곡 ‘APT.’(아파트)가 발매 직후부터 뜨거운 인기를 구가하며 온갖 기록을 갈아치우고 있다.로제와 브루노 마스의 ‘APT.’는 오는 12월 6일 로제의 정식 컴백을 앞두고 발매된 선공개 싱글이다. 이 곡의 뮤직비디오는 공개 5일 만에 1억 뷰를 돌파하고 세계 최대 음원 스트리밍 플랫폼인 스포티파이 글로벌 차트 1위, 멜론·지니 등 국내 주요 음원 차트 1위를 기록했다. 또한, 10월 27일 기준 영국 싱글 차트 1위, 미국 빌보드 메인 싱글 차트 핫 100에도 8위에 오르는 위업을 달성했다.이미지 확대 보기이 곡은 중독성 있는 멜로디와 가사 외에도 특별한 스토리를 담고 있다. 로제가 직접 밝힌 브루노 마스와의 협업 과정이나, ‘APT.’ 발매 이후 일어난 다양한 부수적 효과 등 이 곡을 둘러싼 모든 이야기가 연일 화제를 모은다.먼저 익히 알려진대로 이 곡은 국내의 술자리 게임인 ‘아파트 게임’에서 모티브를 얻었다. 뮤직비디오와 가사에 등장하는 실제 게임의 요소들은 해외 팬들의 궁금증을 자극하는 동시에 국내 팬들에게는 반가움을 안겨주었다. K팝이 한국의 독특한 문화를 세계에 알리는 데 톡톡히 역할을 하고 있음을 보여주는 흥미로운 사례로 남게 됐다.이 가운데 1982년에 발표된 윤수일의 히트곡 ‘아파트’도 재조명을 받고 있다. 두 곡 모두 아파트라는 소재를 사용했으나 전혀 다른 분위기와 메시지를 담아 리스너들에게 또 다른 재미를 주고 있다. 여기에 두 곡을 적절하게 믹스한 콘텐츠까지 등장해 눈길을 끈다. 로제가 의문의 세대 통합을 만들어 낸 셈이다.이미지 확대 보기뿐만 아니라 이 곡은 꽤 특이한 볼거리도 제공했다. ‘APT.’의 선풍적인 인기 덕에 브루노 마스가 한국 음악 방송에서 1위를 차지하게 된 것. 이에 브루노 마스는 SNS에 능청스러운 한국어를 사용해 화답하기도 했다.이 외에도 로제와 브루노 마스의 ‘APT.’는 현재 패러디 영상 콘텐츠, 댄스 챌린지 등 다양한 방식으로 소비되며 단순한 인기 곡이 아닌 사회 현상으로 확산할 조짐을 보이고 있다. 과연 이들의 첫 협업이 끝에 가서는 또 어떤 결실로 맺어질지 귀추가 주목된다.[사진=더블랙레이블, 브루노마스 SNS]YTN star 곽현수 (abroad@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]ADYTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://star.ytn.co.kr/_sn/0117_202410310830016352', 'title': '[Y초점] 로제·브루노 마스, ‘APT.’로 전 세계 접수…신드롬은 이제 시작 | YTN', 'description': '로제와 브루노 마스의 듀엣곡 ‘APT.’(아파트)가 발매 직후부터 뜨거운 인기를 구가하며 온갖 기록을 갈아치우고 있다. 로제와 브루노 마스의 ‘APT.’는 오는 12월 6일 로제...', 'language': 'ko'}
# ------------------------------------
# page_content='[가요]'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권2024.10.22. 오후 3:26.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기이미지 확대 보기사진제공 = 더블랙레이블AD그룹 블랙핑크 로제와 팝스타 브루노 마스의 듀엣 곡이 국내외 음원차트를 강타했다.로제의 새 싱글 'APT.'는 지난 18일 발매 직후 국내 음원사이트 멜론, 지니, 벅스, 바이브 등의 차트에서 1위를 석권했다.해외 차트에서도 반응이 좋다. 'APT.'는 스포티파이 글로벌 차트와 미국 차트 1위에 안착했고, 총 40개 지역 아이튠즈 차트에서도 1위를 차지했다.브루노 마스와 로제가 함께 출연한 'APT.'의 뮤직비디오 역시 뜨거운 반응을 얻고 있다. 뮤직비디오는 유튜브 인기 급상승 동영상 1위, 인기 급상승 음악 1위를 모두 차지했고, 대한민국과 미국의 트렌딩 1위에도 올랐다. 공개 4일 만인 오늘(22일) 8,200만 뷰를 달성했다.선공개 싱글 'APT.'는 한국에서 널리 알려진 '아파트 게임'에서 착안한 곡이다. 반복되는 '아파트'라는 가사가 재치 있다.로제는 "'아파트 게임'은 제가 정말 좋아하는 게임으로, 간단하면서 재미있고 분위기를 띄우는 데 최적이다. 어느 날 밤 스튜디오에서 함께 작업하던 스태프들에게 게임 방법을 알려 주고 다 같이 즐기는 모습을 보며 곡 작업을 시작했고, 브루노 마스가 합류해 이 곡이 완성됐다"고 설명했다.'APT.'가 수록되는 로제의 첫 번째 정규 앨범 '로지(rosie)'는 오는 12월 6일 발매된다.YTN star 오지원 (bluejiwon@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]ADYTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://star.ytn.co.kr/_sn/0117_202410221526301537_001', 'title': "[가요]'아파트, 아파트' 중독성 강하다…로제 'APT.', 국내외 차트 석권 | YTN", 'description': '그룹 블랙핑크 로제와 팝스타 브루노 마스의 듀엣 곡이 국내외 음원차트를 강타했다. 로제의 새 싱글 ', 'language': 'ko'}
# ------------------------------------
# page_content='[문화]로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁2024.10.24. 오전 00:27.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD[앵커]블랙핑크 로제의 신곡 '아파트'의 뮤직비디오가 발표 닷새 만에 1억 조회 수를 돌파했습니다.가수들의 솔로 대결에도 불이 붙었는데, 연말까지 치열한 경쟁이 이어질 전망입니다.이경국 기자입니다.[기자]그룹 블랙핑크의 로제가 팝스타 브루노 마스와 함께 부른 솔로 곡, '아파트'가 신드롬을 일으키고 있습니다.1980년대 히트곡 '미키'의 사운드를 활용한 경쾌한 곡에 'K-술 게임'에서 아이디어를 얻은 재치 있는 가사까지.최고의 협업이란 평가가 이어졌고, '최강의 수능 금지곡'이라는 타이틀까지 얻었습니다.인기에 힘입어 뮤직비디오의 유튜브 조회 수는 공개 닷새 만에 1억 회를 돌파했고,국내 음원 차트 1위를 석권한 것은 물론, 세계 최대 음원 플랫폼 스포티파이의 글로벌 차트 1위까지 차지했습니다.[로제·브루노 마스 : APT.(아파트) 많이 사랑해주세요.]같은 그룹의 멤버 제니도 솔로 곡 '만트라'로 인기몰이 중입니다.자신을 있는 그대로 사랑하자는 메시지를 담은 이번 신곡.빌보드 메인 싱글 차트 '핫 100'에 진입하는 등 또 한 번 기록을 써내려가고 있습니다.그룹 에스파의 카리나가 처음 단독 작사한 솔로 곡 '업'도 화제입니다.콘서트에서만 선보인 미공개 곡이었지만, SNS에서 화제가 된 뒤 정식 발매됐고, 이후 차트 상위권을 굳건히 지키고 있습니다.남자 가수들의 솔로 컴백도 줄줄이 예정돼 있습니다.BTS 진은 다음 달 15일, 솔로 앨범 '해피'를 발표하는데, 최근 콘셉트 영상과 트랙리스트 등을 잇달아 공개하며 예열에 나섰습니다.지드래곤의 컴백에도 관심이 쏠립니다.9년 만의 '마마 어워즈' 출연 소식이 전해진 데 이어, 컴백을 암시하는 SNS 게시글이 올라오며 기대감은 커지고 있습니다.YTN 이경국입니다.영상편집 : 김희정YTN 이경국 (sunny@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]AD문화기사목록 전체보기봉준호 차기작은 첫 장편 애니 '앨리'...내년 상반기 제작 목표[컬처인사이드]공포 영화 '살목지'...김혜윤이 꼽은 관전 포인트는?악동뮤지션, 오는 7일 신보 발매...'소문의 낙원' 뮤직비디오 공개BTS, 오늘 '아리랑' 디럭스 LP 발매...신곡도 수록YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://ytn.co.kr/_ln/0106_202410240027036166', 'title': "[문화]로제 '아파트' 1억 뷰 돌파...불붙은 솔로 경쟁 | YTN", 'description': '블랙핑크 로제의 신곡 ', 'language': 'ko'}
# ------------------------------------
# page_content='[가요]로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북엑스밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난동계올림픽시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법이슈톺TV프로그램프로그램별날짜별앵커 소개시청자의견장애인 서비스검색하기로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성2025.01.02. 오전 11:23.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기이미지 확대 보기AD로제(ROSE)와 브루노 마스(Bruno Mars)가 2024년 마지막 써클차트에서도 1위를 차지했다.오늘(2일) 한국음악콘텐츠협회가 발표한 2024년 52주 차(12월 22일~28일) 써클차트에서 로제와 브루노 마스는 디지털 차트, 글로벌 K-pop 차트, 스트리밍 차트 1위에 올라 3관왕을 차지했다.로제의 정규 1집 '‘rosie’의 선공개 싱글 'APT.'는 써클지수 19,917,013을 기록하며 두 아티스트의 글로벌 인기를 입증했다. 이 곡은 특히 글로벌 K-pop 차트와 스트리밍 차트에서 10주 연속 1위를 유지하며 장기 흥행 중이다.드림캐쳐는 '[My Christmas Sweet Love] (POCA)'로 리테일 앨범 차트 1위를 차지하며 10,563장의 소매점 판매량을 기록했다. 아름다운 캐롤 분위기를 담은  타이틀곡 'My Christmas Sweet Love'가 팬들의 사랑을 받고 있다.아이린(IRENE)의 첫 솔로 앨범 'Like A Flower - The 1st Mini Album (SMC)'은 34,874장의 앨범 판매량을 기록하며 앨범 차트 1위에 올랐다. 이 앨범은 타이틀곡 'Like A Flower'를 포함한 8곡의 수록곡으로 아이린의 새로운 음악적 색깔을 선보인다.BGM 차트, V 컬러링 차트, 벨소리 차트, 통화연결음 차트, 노래방 차트에서는 황가람의 '나는 반딧불'이 모두 1위를 차지하며 5관왕에 올랐다. 이 곡은 험난한 세상 속 별들에게 바치는 메시지를 담아 감동을 전했다.소셜 차트 2.0에서는 FIFTY FIFTY가 3주 연속 정상을 차지했다. 마이셀럽스의 매력 키워드는 ‘상승세를 보이는’, ‘댄스가 걸크러시인’, ‘그루브가 가미된’ 등으로 분석됐다.디지털 차트 200위권 내에는 ▲포레스텔라(Forestella)의 '그리고 봄'(119위), ▲프로미스나인(fromis_9)의 'from'(198위) 등이 새롭게 진입했다.[사진=더블랙레이블]YTN star 곽현수 (abroad@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]ADYTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고채널 안내앵커 소개리더스 뉴스레터경품이벤트위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://star.ytn.co.kr/_sn/0117_202501021123559073', 'title': '[가요]로제·브루노 마스, 2024년 마지막 써클차트 3관왕 달성 | YTN', 'description': '로제(ROSE)와 브루노 마스(Bruno Mars)가 2024년 마지막 써클차트에서도 1위를 차지했다. 오늘(2일) 한국음악콘텐츠협회가 발표한 2024년 52주 차(12월 22일~28일) 써클차...', 'language': 'ko'}
# ------------------------------------

# %%
# 주어진 URL에서 텍스트를 가져오는 함수 만들기

import requests
from bs4 import BeautifulSoup

# 주어진 URL에서 기사 텍스트를 가져오는 함수
def get_article_text(url):
    try:
        # URL에 GET 요청을 보냄
        response = requests.get(url)
        # 요청이 성공하지 못하면 예외를 발생시킴
        response.raise_for_status()

        # BeautifulSoup을 사용하여 HTML 내용 파싱
        soup = BeautifulSoup(response.content, 'html.parser')

        # 클래스가 'story-news article'인 <article> 태그 찾기
        article = soup.find('article', class_='story-news article')

        # 기사를 찾았다면 그 텍스트를 반환
        if article:
            return article.get_text(strip=True)
        else:
            try:
                if soup.find('article'):
                    return soup.find('article').get_text(strip=True)
                elif soup.find('div', id='CmAdContent'):
                    return soup.find('div', id="CmAdContent").get_text(strip=True)
            except:
                return "기사 내용을 찾을 수 없습니다."
            

    except requests.exceptions.RequestException as e:
        return f"URL을 가져오는 중 오류 발생: {e}"

# %%
def get_article_text(url):
    try:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
        }
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')

        # 여러 selector 순서대로 시도
        selectors = [
            ('article', {'class': 'story-news article'}),
            ('article', {}),
            ('div', {'id': 'CmAdContent'}),
            ('div', {'class': 'article-content'}),
            ('div', {'id': 'article-view-content-div'}),  # YTN 뉴스 본문
        ]

        for tag, attrs in selectors:
            element = soup.find(tag, attrs) if attrs else soup.find(tag)
            if element:
                return element.get_text(strip=True)

        return "기사 내용을 찾을 수 없습니다."

    except requests.exceptions.RequestException as e:
        return f"URL을 가져오는 중 오류 발생: {e}"

# %%
# 주어진 URL에서 텍스트 가져오기

# URL 목록의 각 링크를 반복하면서 기사 텍스트 출력
articles = [] # 가져온 내용을 리스트에 담는 변수 선언
for link in links:
    print(f"URL: {link}\n")
    article_text = get_article_text(link)
    print(f"Content:\n{article_text}")
    print("---------------------------------------------")
    articles.append(article_text)
# Out:
# URL: https://star.ytn.co.kr/_sn/0117_202410310830016352
#
# Content:
# 로제와 브루노 마스의 듀엣곡 ‘APT.’(아파트)가 발매 직후부터 뜨거운 인기를 구가하며 온갖 기록을 갈아치우고 있다.로제와 브루노 마스의 ‘APT.’는 오는 12월 6일 로제의 정식 컴백을 앞두고 발매된 선공개 싱글이다. 이 곡의 뮤직비디오는 공개 5일 만에 1억 뷰를 돌파하고 세계 최대 음원 스트리밍 플랫폼인 스포티파이 글로벌 차트 1위, 멜론·지니 등 국내 주요 음원 차트 1위를 기록했다. 또한, 10월 27일 기준 영국 싱글 차트 1위, 미국 빌보드 메인 싱글 차트 핫 100에도 8위에 오르는 위업을 달성했다.이미지 확대 보기이 곡은 중독성 있는 멜로디와 가사 외에도 특별한 스토리를 담고 있다. 로제가 직접 밝힌 브루노 마스와의 협업 과정이나, ‘APT.’ 발매 이후 일어난 다양한 부수적 효과 등 이 곡을 둘러싼 모든 이야기가 연일 화제를 모은다.먼저 익히 알려진대로 이 곡은 국내의 술자리 게임인 ‘아파트 게임’에서 모티브를 얻었다. 뮤직비디오와 가사에 등장하는 실제 게임의 요소들은 해외 팬들의 궁금증을 자극하는 동시에 국내 팬들에게는 반가움을 안겨주었다. K팝이 한국의 독특한 문화를 세계에 알리는 데 톡톡히 역할을 하고 있음을 보여주는 흥미로운 사례로 남게 됐다.이 가운데 1982년에 발표된 윤수일의 히트곡 ‘아파트’도 재조명을 받고 있다. 두 곡 모두 아파트라는 소재를 사용했으나 전혀 다른 분위기와 메시지를 담아 리스너들에게 또 다른 재미를 주고 있다. 여기에 두 곡을 적절하게 믹스한 콘텐츠까지 등장해 눈길을 끈다. 로제가 의문의 세대 통합을 만들어 낸 셈이다.이미지 확대 보기뿐만 아니라 이 곡은 꽤 특이한 볼거리도 제공했다. ‘APT.’의 선풍적인 인기 덕에 브루노 마스가 한국 음악 방송에서 1위를 차지하게 된 것. 이에 브루노 마스는 SNS에 능청스러운 한국어를 사용해 화답하기도 했다.이 외에도 로제와 브루노 마스의 ‘APT.’는 현재 패러디 영상 콘텐츠, 댄스 챌린지 등 다양한 방식으로 소비되며 단순한 인기 곡이 아닌 사회 현상으로 확산할 조짐을 보이고 있다. 과연 이들의 첫 협업이 끝에 가서는 또 어떤 결실로 맺어질지 귀추가 주목된다.[사진=더블랙레이블, 브루노마스 SNS]YTN star 곽현수 (abroad@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ---------------------------------------------
# URL: https://star.ytn.co.kr/_sn/0117_202410221526301537_001
#
# Content:
# 그룹 블랙핑크 로제와 팝스타 브루노 마스의 듀엣 곡이 국내외 음원차트를 강타했다.로제의 새 싱글 'APT.'는 지난 18일 발매 직후 국내 음원사이트 멜론, 지니, 벅스, 바이브 등의 차트에서 1위를 석권했다.해외 차트에서도 반응이 좋다. 'APT.'는 스포티파이 글로벌 차트와 미국 차트 1위에 안착했고, 총 40개 지역 아이튠즈 차트에서도 1위를 차지했다.브루노 마스와 로제가 함께 출연한 'APT.'의 뮤직비디오 역시 뜨거운 반응을 얻고 있다. 뮤직비디오는 유튜브 인기 급상승 동영상 1위, 인기 급상승 음악 1위를 모두 차지했고, 대한민국과 미국의 트렌딩 1위에도 올랐다. 공개 4일 만인 오늘(22일) 8,200만 뷰를 달성했다.선공개 싱글 'APT.'는 한국에서 널리 알려진 '아파트 게임'에서 착안한 곡이다. 반복되는 '아파트'라는 가사가 재치 있다.로제는 "'아파트 게임'은 제가 정말 좋아하는 게임으로, 간단하면서 재미있고 분위기를 띄우는 데 최적이다. 어느 날 밤 스튜디오에서 함께 작업하던 스태프들에게 게임 방법을 알려 주고 다 같이 즐기는 모습을 보며 곡 작업을 시작했고, 브루노 마스가 합류해 이 곡이 완성됐다"고 설명했다.'APT.'가 수록되는 로제의 첫 번째 정규 앨범 '로지(rosie)'는 오는 12월 6일 발매된다.YTN star 오지원 (bluejiwon@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ---------------------------------------------
# URL: https://ytn.co.kr/_ln/0106_202410240027036166
#
# Content:
# [앵커]블랙핑크 로제의 신곡 '아파트'의 뮤직비디오가 발표 닷새 만에 1억 조회 수를 돌파했습니다.가수들의 솔로 대결에도 불이 붙었는데, 연말까지 치열한 경쟁이 이어질 전망입니다.이경국 기자입니다.[기자]그룹 블랙핑크의 로제가 팝스타 브루노 마스와 함께 부른 솔로 곡, '아파트'가 신드롬을 일으키고 있습니다.1980년대 히트곡 '미키'의 사운드를 활용한 경쾌한 곡에 'K-술 게임'에서 아이디어를 얻은 재치 있는 가사까지.최고의 협업이란 평가가 이어졌고, '최강의 수능 금지곡'이라는 타이틀까지 얻었습니다.인기에 힘입어 뮤직비디오의 유튜브 조회 수는 공개 닷새 만에 1억 회를 돌파했고,국내 음원 차트 1위를 석권한 것은 물론, 세계 최대 음원 플랫폼 스포티파이의 글로벌 차트 1위까지 차지했습니다.[로제·브루노 마스 : APT.(아파트) 많이 사랑해주세요.]같은 그룹의 멤버 제니도 솔로 곡 '만트라'로 인기몰이 중입니다.자신을 있는 그대로 사랑하자는 메시지를 담은 이번 신곡.빌보드 메인 싱글 차트 '핫 100'에 진입하는 등 또 한 번 기록을 써내려가고 있습니다.그룹 에스파의 카리나가 처음 단독 작사한 솔로 곡 '업'도 화제입니다.콘서트에서만 선보인 미공개 곡이었지만, SNS에서 화제가 된 뒤 정식 발매됐고, 이후 차트 상위권을 굳건히 지키고 있습니다.남자 가수들의 솔로 컴백도 줄줄이 예정돼 있습니다.BTS 진은 다음 달 15일, 솔로 앨범 '해피'를 발표하는데, 최근 콘셉트 영상과 트랙리스트 등을 잇달아 공개하며 예열에 나섰습니다.지드래곤의 컴백에도 관심이 쏠립니다.9년 만의 '마마 어워즈' 출연 소식이 전해진 데 이어, 컴백을 암시하는 SNS 게시글이 올라오며 기대감은 커지고 있습니다.YTN 이경국입니다.영상편집 : 김희정YTN 이경국 (sunny@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ---------------------------------------------
# URL: https://star.ytn.co.kr/_sn/0117_202501021123559073
#
# Content:
# 로제(ROSE)와 브루노 마스(Bruno Mars)가 2024년 마지막 써클차트에서도 1위를 차지했다.오늘(2일) 한국음악콘텐츠협회가 발표한 2024년 52주 차(12월 22일~28일) 써클차트에서 로제와 브루노 마스는 디지털 차트, 글로벌 K-pop 차트, 스트리밍 차트 1위에 올라 3관왕을 차지했다.로제의 정규 1집 '‘rosie’의 선공개 싱글 'APT.'는 써클지수 19,917,013을 기록하며 두 아티스트의 글로벌 인기를 입증했다. 이 곡은 특히 글로벌 K-pop 차트와 스트리밍 차트에서 10주 연속 1위를 유지하며 장기 흥행 중이다.드림캐쳐는 '[My Christmas Sweet Love] (POCA)'로 리테일 앨범 차트 1위를 차지하며 10,563장의 소매점 판매량을 기록했다. 아름다운 캐롤 분위기를 담은  타이틀곡 'My Christmas Sweet Love'가 팬들의 사랑을 받고 있다.아이린(IRENE)의 첫 솔로 앨범 'Like A Flower - The 1st Mini Album (SMC)'은 34,874장의 앨범 판매량을 기록하며 앨범 차트 1위에 올랐다. 이 앨범은 타이틀곡 'Like A Flower'를 포함한 8곡의 수록곡으로 아이린의 새로운 음악적 색깔을 선보인다.BGM 차트, V 컬러링 차트, 벨소리 차트, 통화연결음 차트, 노래방 차트에서는 황가람의 '나는 반딧불'이 모두 1위를 차지하며 5관왕에 올랐다. 이 곡은 험난한 세상 속 별들에게 바치는 메시지를 담아 감동을 전했다.소셜 차트 2.0에서는 FIFTY FIFTY가 3주 연속 정상을 차지했다. 마이셀럽스의 매력 키워드는 ‘상승세를 보이는’, ‘댄스가 걸크러시인’, ‘그루브가 가미된’ 등으로 분석됐다.디지털 차트 200위권 내에는 ▲포레스텔라(Forestella)의 '그리고 봄'(119위), ▲프로미스나인(fromis_9)의 'from'(198위) 등이 새롭게 진입했다.[사진=더블랙레이블]YTN star 곽현수 (abroad@ytn.co.kr)* YTN star에서는 연예인 및 연예계 종사자들과 관련된 제보를 받습니다.ytnstar@ytn.co.kr로 언제든 연락주시기 바랍니다. 감사합니다.[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ---------------------------------------------

# %%
# 검색된 뉴스 기사 본문 결과를 이용하여 답변 생성
chat_history.add_user_message("로제의 신곡 APT에 대한 반응")

# 문서 검색하고 답변 생성
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
